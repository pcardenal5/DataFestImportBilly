# %%
# Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestRegressor

import xgboost as xgb
from xgboost import XGBRegressor

import scipy as scp
import scipy.stats as stats

import optuna
from optuna.integration import OptunaSearchCV

from datetime import datetime, timedelta
import calendar

# %% [markdown]
# ## Functions

# %%
def root_mean_squared_error(y_true, y_pred):
    """
    :param y_true: a list of true target values
    :param y_pred: a list of predicted target values
    :return: rmse
    """
    mse = ((y_true - y_pred) ** 2).mean()
    rmse = np.sqrt(mse)
    return rmse

def random_forest(x_train, x_test, y_train, params: dict = None):

    # Model #
    params ['criterion'] = 'squared_error'
    params ['random_state'] = 0

    RF_model = RandomForestRegressor(**params) 

    # Fit #
    RF_model.fit(x_train,y_train)

    # Predict #
    y_pred = RF_model.predict(x_test)

    return y_pred

def xgboost(x_train, x_test, y_train, params: dict = None):
        
    # Model #
    params['objective'] = 'reg:squarederror'

    XGB_model = XGBRegressor(**params)
    
    # Fit #
    XGB_model.fit(x_train, y_train)

    # Predict #
    y_pred = XGB_model.predict(x_test)

    return y_pred

def optuna_search(X_train: pd.DataFrame, y_train: pd.Series, estimator: str = 'RF'):

    if estimator not in ['RF', 'XGB']:
        raise ValueError("Estimator must be 'RF' or 'XGB'.")
    
    k_folds = 10
    n_trials = 5
    
    if estimator == 'RF':
        estimator = RandomForestRegressor(criterion='squared_error', random_state=0)
        param_distributions = {
            'n_estimators': optuna.distributions.IntDistribution(10, 250),
            'max_features': optuna.distributions.IntDistribution(1, len(INPUTS)),
            'max_depth': optuna.distributions.IntDistribution(1, 20),
            'min_samples_split': optuna.distributions.IntDistribution(2, 10),
            'min_samples_leaf':optuna.distributions.IntDistribution(1, 10),
            'min_impurity_decrease': optuna.distributions.FloatDistribution(0.001, 0.1)
            }
        rf_opt = OptunaSearchCV(estimator, param_distributions=param_distributions, n_trials = n_trials, cv=k_folds, verbose=False)
        rf_opt.fit(X_train, y_train)
        return rf_opt.best_params_, rf_opt.best_score_
    
    else:

        estimator = XGBRegressor(objective = 'reg:squarederror', random_state=0)
        param_distributions = {
            'n_estimators': optuna.distributions.IntDistribution(10, 250),
            'learning_rate': optuna.distributions.FloatDistribution(0.001, 1),
            'max_depth': optuna.distributions.IntDistribution(1, 5),
            'min_split_loss': optuna.distributions.FloatDistribution(0.001, 1)
        }
        xgb_opt = OptunaSearchCV(estimator, param_distributions=param_distributions, n_trials = n_trials, cv=k_folds, verbose=False)
        xgb_opt.fit(X_train, y_train)
        return xgb_opt.best_params_, xgb_opt.best_score_

# %% [markdown]
# ## Preprocess

# %% [markdown]
# #### EDA

# %%
# Read data
df = pd.read_csv('C:/Users\/juanm/Escritorio/Juanmi/DataFest IKEA/Team 09. ImportBilly/1. Data/visits_train.csv')
df.head()
# Out:
#   location  date_visit     visits
# 0   Madrid  28-02-2023  67.323720
# 1   Madrid  27-02-2023  71.894430
# 2   Madrid  26-02-2023  87.803810
# 3   Madrid  25-02-2023  90.435243
# 4   Madrid  24-02-2023  76.281122

# %%
df['date_visit'] = pd.to_datetime(df['date_visit'], format='%d-%m-%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    1338 non-null   object
#  1   date_visit  1338 non-null   datetime64[ns]
#  2   visits      1338 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 31.5+ KB

# %%
df.describe()
# Out:
#             visits
# count  1338.000000
# mean     58.837301
# std      16.243328
# min       0.000000
# 25%      50.429277
# 50%      59.213881
# 75%      67.605966
# max     101.000000

# %%
miss_data = pd.isnull(df).values.any()
print("Hay información perdida: ", miss_data, "\n")

sum_miss_data = pd.isnull(df).sum()
print("Hay {} valores perdidos".format(sum_miss_data))
# Out:
# Hay información perdida:  False
#
# Hay location      0
# date_visit    0
# visits        0
# dtype: int64 valores perdidos

# %%
# Duplicates
df.duplicated().value_counts()
# Out:
# False    1338
# dtype: int64

# %%
# Porcentaje de ceros
variables = ['location', 'date_visit', 'visits']
for i in variables:
    df_count=df.loc[df[i] == 0]
    x=(df_count[i].count()/df[i].count())*100
    x=round(x,2)
    print(f'The Number of zero values in column {i} is {x}')
# Out:
# The Number of zero values in column location is 0.0
# The Number of zero values in column date_visit is 0.0
# The Number of zero values in column visits is 2.62

# %%
# Vemos los días que no hay visitas
df[df.visits < 1]
# Out:
#        location date_visit  visits
# 53       Madrid 2023-01-06     0.0
# 734   Barcelona 2022-12-25     0.0
# 783   Barcelona 2022-11-06     0.0
# 804   Barcelona 2022-10-16     0.0
# 818   Barcelona 2022-10-02     0.0
# 888   Barcelona 2022-07-24     0.0
# 895   Barcelona 2022-07-17     0.0
# 902   Barcelona 2022-07-10     0.0
# 909   Barcelona 2022-07-03     0.0
# 918   Barcelona 2022-06-24     0.0
# 937   Barcelona 2022-06-05     0.0
# 944   Barcelona 2022-05-29     0.0
# 958   Barcelona 2022-05-15     0.0
# 965   Barcelona 2022-05-08     0.0
# 972   Barcelona 2022-05-01     0.0
# 985   Barcelona 2022-04-18     0.0
# 986   Barcelona 2022-04-17     0.0
# 1035  Barcelona 2022-02-27     0.0
# 1063  Barcelona 2022-01-30     0.0
# 1099  Barcelona 2021-12-25     0.0
# 1161  Barcelona 2021-10-24     0.0
# 1168  Barcelona 2021-10-17     0.0
# 1182  Barcelona 2021-10-03     0.0
# 1196  Barcelona 2021-09-19     0.0
# 1204  Barcelona 2021-09-11     0.0
# 1217  Barcelona 2021-08-29     0.0
# 1252  Barcelona 2021-07-25     0.0
# 1266  Barcelona 2021-07-11     0.0
# 1287  Barcelona 2021-06-20     0.0
# 1301  Barcelona 2021-06-06     0.0
# 1308  Barcelona 2021-05-30     0.0
# 1315  Barcelona 2021-05-23     0.0
# 1322  Barcelona 2021-05-16     0.0
# 1329  Barcelona 2021-05-09     0.0
# 1337  Barcelona 2021-05-01     0.0

# %% [markdown]
# # Forecast

# %%
df_mad = df[df['location']=='Madrid'].drop(['location'], axis=1).reset_index(drop=True)

# %%
df_bar = df[df['location']=='Barcelona'].drop(['location'], axis=1).reset_index(drop=True)

# %%
# Index
df_mad = df_mad.set_index('date_visit').sort_index(ascending=True)
df_bar = df_bar.set_index('date_visit').sort_index(ascending=True)

# %%
df_mad
# Out:
#                visits
# date_visit
# 2021-05-01  29.393306
# 2021-05-02  78.272126
# 2021-05-03  73.994576
# 2021-05-04  48.882127
# 2021-05-05  45.836089
# ...               ...
# 2023-02-24  76.281122
# 2023-02-25  90.435243
# 2023-02-26  87.803810
# 2023-02-27  71.894430
# 2023-02-28  67.323720
#
# [669 rows x 1 columns]

# %%
# Crea un rango de fechas para marzo de 2023
start_date = datetime(2023, 3, 1)
end_date = datetime(2023, 4, 1) - timedelta(days=1)
date_range = pd.date_range(start_date, end_date)

# Convierte el rango de fechas en una lista de cadenas con formato 'yyyy-mm-dd'
df_marzo = pd.DataFrame([date.strftime('%Y-%m-%d') for date in date_range])
df_marzo = df_marzo.set_index(0)

# %%
df_mad = pd.concat([df_mad, df_marzo], axis=1)
df_bar = pd.concat([df_bar, df_marzo], axis=1)

# %%
df_mad = df_mad.reset_index(drop=False, names=['date_visit'])
df_bar = df_bar.reset_index(drop=False, names=['date_visit'])
# Out:
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\345413761.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   df_mad = df_mad.reset_index(drop=False, names=['date_visit'])
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\345413761.py:2: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   df_bar = df_bar.reset_index(drop=False, names=['date_visit'])

# %% [markdown]
# ### Opt. Parámetros

# %%
# Lags
df_mad_aux = df_mad.copy()
df_bar_aux = df_bar.copy()
for i in range(1, 31):
    df_mad_aux[f"lag_{i}"] = df_mad["visits"].shift(i)
    df_bar_aux[f"lag_{i}"] = df_bar["visits"].shift(i)
df_mad_aux = df_mad_aux.dropna().set_index('date_visit')
df_bar_aux = df_bar_aux.dropna().set_index('date_visit')

# %%
INPUTS = df_bar_aux.columns.drop('visits')
OUTPUT = 'visits'

# %% [markdown]
# * Barcelona

# %%
x_train = df_bar_aux[INPUTS]
y_train = df_bar_aux[OUTPUT]

# %%
### Optuna General ###
rf_params_bar, rf_scorer = optuna_search(x_train, y_train, 'RF')
xgb_params_bar, xgb_scorer = optuna_search(x_train, y_train, 'XGB')
# Out:
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1937983928.py:60: ExperimentalWarning: OptunaSearchCV is experimental (supported from v0.17.0). The interface can change in the future.
#   rf_opt = OptunaSearchCV(estimator, param_distributions=param_distributions, n_trials = n_trials, cv=k_folds, verbose=False)
# [I 2023-04-16 11:20:21,234] A new study created in memory with name: no-name-1612ffd5-cc31-40a1-9f47-65bb69fd7859
# [I 2023-04-16 11:20:26,724] Trial 0 finished with value: 0.49788755351854486 and parameters: {'n_estimators': 249, 'max_features': 15, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 8, 'min_impurity_decrease': 0.08474336364982674}. Best is trial 0 with value: 0.49788755351854486.
# [I 2023-04-16 11:20:29,564] Trial 1 finished with value: 0.5035013048953262 and parameters: {'n_estimators': 57, 'max_features': 25, 'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 5, 'min_impurity_decrease': 0.003308679060639942}. Best is trial 1 with value: 0.5035013048953262.
# [I 2023-04-16 11:20:34,942] Trial 2 finished with value: 0.5047601191622961 and parameters: {'n_estimators': 129, 'max_features': 26, 'max_depth': 10, 'min_samples_split': 8, 'min_samples_leaf': 10, 'min_impurity_decrease': 0.08127990417009597}. Best is trial 2 with value: 0.5047601191622961.
# [I 2023-04-16 11:20:36,139] Trial 3 finished with value: 0.5029816341866526 and parameters: {'n_estimators': 35, 'max_features': 18, 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 8, 'min_impurity_decrease': 0.01783066038314111}. Best is trial 2 with value: 0.5047601191622961.
# [I 2023-04-16 11:20:37,245] Trial 4 finished with value: 0.42678610252997107 and parameters: {'n_estimators': 54, 'max_features': 24, 'max_depth': 2, 'min_samples_split': 7, 'min_samples_leaf': 7, 'min_impurity_decrease': 0.01820291698273372}. Best is trial 2 with value: 0.5047601191622961.
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1937983928.py:73: ExperimentalWarning: OptunaSearchCV is experimental (supported from v0.17.0). The interface can change in the future.
#   xgb_opt = OptunaSearchCV(estimator, param_distributions=param_distributions, n_trials = n_trials, cv=k_folds, verbose=False)
# [I 2023-04-16 11:20:37,850] A new study created in memory with name: no-name-f7ceaf59-dd2a-4761-aeef-53d5f330416b
# [I 2023-04-16 11:20:38,514] Trial 0 finished with value: 0.4696905589458605 and parameters: {'n_estimators': 205, 'learning_rate': 0.154999463319577, 'max_depth': 1, 'min_split_loss': 0.7529483480039466}. Best is trial 0 with value: 0.4696905589458605.
# [I 2023-04-16 11:20:39,347] Trial 1 finished with value: 0.3758728669612562 and parameters: {'n_estimators': 136, 'learning_rate': 0.10043997203633122, 'max_depth': 4, 'min_split_loss': 0.26930629221219365}. Best is trial 0 with value: 0.4696905589458605.
# [I 2023-04-16 11:20:39,934] Trial 2 finished with value: 0.2293112584940385 and parameters: {'n_estimators': 134, 'learning_rate': 0.49816118063994225, 'max_depth': 2, 'min_split_loss': 0.9233977898615858}. Best is trial 0 with value: 0.4696905589458605.
# [I 2023-04-16 11:20:40,444] Trial 3 finished with value: 0.3466868186353175 and parameters: {'n_estimators': 64, 'learning_rate': 0.1504268255073135, 'max_depth': 5, 'min_split_loss': 0.12203908108103036}. Best is trial 0 with value: 0.4696905589458605.
# [I 2023-04-16 11:20:40,881] Trial 4 finished with value: -0.05225916071891919 and parameters: {'n_estimators': 62, 'learning_rate': 0.9766611728016893, 'max_depth': 4, 'min_split_loss': 0.7933965545830187}. Best is trial 0 with value: 0.4696905589458605.

# %% [markdown]
# * Madrid

# %%
x_train = df_mad_aux[INPUTS]
y_train = df_mad_aux[OUTPUT]

# %%
### Optuna General ###
rf_params_mad, rf_scorer = optuna_search(x_train, y_train, 'RF')
xgb_params_mad, xgb_scorer = optuna_search(x_train, y_train, 'XGB')
# Out:
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1937983928.py:60: ExperimentalWarning: OptunaSearchCV is experimental (supported from v0.17.0). The interface can change in the future.
#   rf_opt = OptunaSearchCV(estimator, param_distributions=param_distributions, n_trials = n_trials, cv=k_folds, verbose=False)
# [I 2023-04-16 11:20:41,077] A new study created in memory with name: no-name-6077912e-3e1d-4be3-9661-e711175176fe
# [I 2023-04-16 11:20:42,030] Trial 0 finished with value: 0.42993529028034666 and parameters: {'n_estimators': 79, 'max_features': 5, 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 3, 'min_impurity_decrease': 0.08261487147859495}. Best is trial 0 with value: 0.42993529028034666.
# [I 2023-04-16 11:20:48,607] Trial 1 finished with value: 0.5222042884683206 and parameters: {'n_estimators': 233, 'max_features': 11, 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 1, 'min_impurity_decrease': 0.034855654826056064}. Best is trial 1 with value: 0.5222042884683206.
# [I 2023-04-16 11:20:52,965] Trial 2 finished with value: 0.5597490699841059 and parameters: {'n_estimators': 90, 'max_features': 30, 'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 8, 'min_impurity_decrease': 0.057510605959599975}. Best is trial 2 with value: 0.5597490699841059.
# [I 2023-04-16 11:20:57,579] Trial 3 finished with value: 0.5438256468399898 and parameters: {'n_estimators': 241, 'max_features': 7, 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 5, 'min_impurity_decrease': 0.0773267839245632}. Best is trial 2 with value: 0.5597490699841059.
# [I 2023-04-16 11:20:58,809] Trial 4 finished with value: 0.44590572175426263 and parameters: {'n_estimators': 115, 'max_features': 2, 'max_depth': 13, 'min_samples_split': 5, 'min_samples_leaf': 9, 'min_impurity_decrease': 0.07327173589130295}. Best is trial 2 with value: 0.5597490699841059.
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1937983928.py:73: ExperimentalWarning: OptunaSearchCV is experimental (supported from v0.17.0). The interface can change in the future.
#   xgb_opt = OptunaSearchCV(estimator, param_distributions=param_distributions, n_trials = n_trials, cv=k_folds, verbose=False)
# [I 2023-04-16 11:20:59,294] A new study created in memory with name: no-name-f0b3b560-876d-4aeb-95c1-9a6a3c8b47b2
# [I 2023-04-16 11:20:59,906] Trial 0 finished with value: 0.45691104353258644 and parameters: {'n_estimators': 169, 'learning_rate': 0.3231857769553824, 'max_depth': 1, 'min_split_loss': 0.08308422949514943}. Best is trial 0 with value: 0.45691104353258644.
# [I 2023-04-16 11:21:01,025] Trial 1 finished with value: 0.3824676713941558 and parameters: {'n_estimators': 213, 'learning_rate': 0.3754646870094361, 'max_depth': 3, 'min_split_loss': 0.46272576467990933}. Best is trial 0 with value: 0.45691104353258644.
# [I 2023-04-16 11:21:01,249] Trial 2 finished with value: 0.5159890327303491 and parameters: {'n_estimators': 44, 'learning_rate': 0.2952418513421496, 'max_depth': 1, 'min_split_loss': 0.6754115370346409}. Best is trial 2 with value: 0.5159890327303491.
# [I 2023-04-16 11:21:01,443] Trial 3 finished with value: 0.2940018665978346 and parameters: {'n_estimators': 26, 'learning_rate': 0.6403227605442422, 'max_depth': 2, 'min_split_loss': 0.4894135257808718}. Best is trial 2 with value: 0.5159890327303491.
# [I 2023-04-16 11:21:02,321] Trial 4 finished with value: 0.3918131119302345 and parameters: {'n_estimators': 134, 'learning_rate': 0.37377117767656026, 'max_depth': 4, 'min_split_loss': 0.30810978580784176}. Best is trial 2 with value: 0.5159890327303491.

# %% [markdown]
# ### Barcelona

# %%
df_bar = df_bar.set_index('date_visit')

# %%
df_rf = df_bar.copy()
df_rf.index = pd.to_datetime(df_rf.index)
df_xgb = df_bar.copy()
df_xgb.index = pd.to_datetime(df_xgb.index)
for i in range(len(df_marzo)):
    date = df_marzo.index[i+1]
    df_aux_rf = df_rf.loc[:date]
    df_aux_xgb = df_xgb.loc[:date]
    # Lags
    for i in range(1, 31):
        df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
        df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
    df_aux_rf = df_aux_rf.dropna()
    df_aux_xgb = df_aux_xgb.dropna()
    x_train_rf = df_aux_rf.iloc[:-1][INPUTS]
    y_train_rf = df_aux_rf.iloc[:-1][OUTPUT]
    x_test_rf = df_aux_rf.loc[date][INPUTS]
    x_train_xgb = df_aux_xgb.iloc[:-1][INPUTS]
    y_train_xgb = df_aux_xgb.iloc[:-1][OUTPUT]
    x_test_xgb = df_aux_xgb.loc[date][INPUTS]
    print(x_train_rf.head())
    print(y_train_rf.head())
    print(x_test_rf.head())
    y_pred_rf = random_forest(x_train_rf, pd.Series(x_test_rf), y_train_rf, rf_params_bar)
    y_pred_xgb = xgboost(x_train_xgb, pd.Series(x_test_xgb), y_train_xgb, rf_params_bar)
    df_rf[df_rf['date_visit'] == date]['visits'] = y_pred_rf
    df_xgb[df_xgb['date_visit'] == date]['visits'] = y_pred_xgb
# Out:
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_rf[f"lag_{i}"] = df_aux_rf["visits"].shift(i)
# C:\Users\juanm\AppData\Local\Temp\ipykernel_29424\1568389208.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aux_xgb[f"lag_{i}"] = df_aux_xgb["visits"].shift(i)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\juanm\miniconda3\envs\datafest\Lib\site-packages\pandas\_libs\index.pyx:548, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1677715200000000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File c:\Users\juanm\miniconda3\envs\datafest\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\juanm\miniconda3\envs\datafest\Lib\site-packages\pandas\_libs\index.pyx:516, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File c:\Users\juanm\miniconda3\envs\datafest\Lib\site-packages\pandas\_libs\index.pyx:550, in pandas._libs.index.DatetimeEngine.get_loc()
#
# KeyError: Timestamp('2023-03-02 00:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File c:\Users\juanm\miniconda3\envs\datafest\Lib\site-packages\pandas\core\indexes\datetimes.py:736, in DatetimeIndex.get_loc(self, key, method, tolerance)
#     735 try:
# --> 736     return Index.get_loc(self, key, method, tolerance)
#     737 except KeyError as err:
#
# File c:\Users\juanm\miniconda3\envs\datafest\Lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#
# KeyError: Timestamp('2023-03-02 00:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[412], line 17
#      15 x_train_rf = df_aux_rf.iloc[:-1][INPUTS]
#      16 y_train_rf = df_aux_rf.iloc[:-1][OUTPUT]
# ---> 17 x_test_rf = df_aux_rf.loc[date][INPUTS]
#      18 x_train_xgb = df_aux_xgb.iloc[:-1][INPUTS]
#      19 y_train_xgb = df_aux_xgb.iloc[:-1][OUTPUT]
#
# File c:\Users\juanm\miniconda3\envs\datafest\Lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\juanm\miniconda3\envs\datafest\Lib\site-packages\pandas\core\indexing.py:1312, in _LocIndexer._getitem_axis(self, key, axis)
#    1310 # fall thru to straight lookup
#    1311 self._validate_key(key, axis)
# -> 1312 return self._get_label(key, axis=axis)
#
# File c:\Users\juanm\miniconda3\envs\datafest\Lib\site-packages\pandas\core\indexing.py:1260, in _LocIndexer._get_label(self, label, axis)
#    1258 def _get_label(self, label, axis: int):
#    1259     # GH#5567 this will fail if the label is not present in the axis.
# -> 1260     return self.obj.xs(label, axis=axis)
#
# File c:\Users\juanm\miniconda3\envs\datafest\Lib\site-packages\pandas\core\generic.py:4056, in NDFrame.xs(self, key, axis, level, drop_level)
#    4054             new_index = index[loc]
#    4055 else:
# -> 4056     loc = index.get_loc(key)
#    4058     if isinstance(loc, np.ndarray):
#    4059         if loc.dtype == np.bool_:
#
# File c:\Users\juanm\miniconda3\envs\datafest\Lib\site-packages\pandas\core\indexes\datetimes.py:738, in DatetimeIndex.get_loc(self, key, method, tolerance)
#     736     return Index.get_loc(self, key, method, tolerance)
#     737 except KeyError as err:
# --> 738     raise KeyError(orig_key) from err
#
# KeyError: '2023-03-02'

# %%
y_pred_rf = random_forest(x_train, pd.Series(x_test), y_train, rf_params)
y_pred_xgb = xgboost(x_train, pd.Series(x_test), y_train, xgb_params)

# %%
y_pred_xgb

# %% [markdown]
# ### Madrid

# %%
y_pred_rf = random_forest(x_train, x_test, y_train, rf_params)
y_pred_xgb = xgboost(x_train, x_test, y_train, xgb_params)

# %%
y_pred_xgb
